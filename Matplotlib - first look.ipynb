# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Tworzenie wykresu prostej

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

# %%
fig = plt.figure()

plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Wykres funkcji y=x")

plt.plot(x, y, label='linear')
plt.legend()

plt.show()

# %% [markdown]
# ### Wykres funkcji trygonometrycznych i nakładanie funkcji na jednym wykresie

# %%
x = np.arange(0, 10, 0.2)
print("x = ", x)
# Out:
# x =  [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8 5.  5.2 5.4 5.6 5.8 6.  6.2 6.4 6.6 6.8 7.
#  7.2 7.4 7.6 7.8 8.  8.2 8.4 8.6 8.8 9.  9.2 9.4 9.6 9.8]

# %%
fig = plt.figure()
plt.plot(x, np.sin(x), label='sinus')
plt.plot(x, np.cos(x), label='cosinus')
plt.legend()

plt.show()

# %% [markdown]
# ### Tworzenie subplotów

# %%
fig = plt.figure()
k, (ax1, ax2) = plt.subplots(2)

ax1.plot(x, np.sin(x), color='green', label='sinus')
ax2.plot(x, np.cos(x), color='orange', label='cosinus')

plt.show()

# %% [markdown]
# #### Lub drugim sposobem

# %%
fig = plt.figure()

plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), color='green', label='sinus')

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), color='orange', label='cosinus')

plt.show()

# %% [markdown]
# ### Wykres słupkowy

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

fig = plt.figure()
plt.bar(names, values)

plt.show()

# %% [markdown]
# ### Histogram z rozkładu normalnego

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Wykres punktowy

# %%
x = np.arange(10, 100, 5)
fig = plt.figure()
plt.scatter(x, np.log(x))

plt.show()

# %%
from sklearn import datasets
import pandas as pd

iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
cols = df.columns.values
combinations = []

for i in range(0, len(cols)):
    for j in range(i+1, len(cols)):
        combinations.append((cols[i], cols[j]))

# %%
fig = plt.figure()

_, subplots = plt.subplots(len(combinations)//2, 2, figsize=(12,30))

subplots = subplots.flatten()
print(len(subplots))
for comb, sub in zip(combinations, subplots):
    sub.scatter(df[comb[0]], df[comb[1]], c=df['target'])
    sub.set_xlabel(comb[0])
    sub.set_ylabel(comb[1])

plt.show()
# Out:
# 10

# %% [markdown]
# ### Dalsze przykłady

# %% [markdown]
# Tutoriale znajdują się na stronie https://matplotlib.org/tutorials/index.html

# %% [markdown]
# ## Seaborn

# %%
sns.pairplot(sns.load_dataset("iris"))
